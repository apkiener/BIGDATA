# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Q. 1

# %%
IMDB = pd.read_csv("imdb_2019.tsv",sep="\t")

# %%
IMDB.head()
# Out:
#       index     tconst titleType                    primaryTitle  \
# 0   87501.0  tt0089435     short                           Kokoa
# 1   89512.0  tt0091490     short             Martina's Playhouse
# 2  114407.0  tt0116991     movie             Mariette in Ecstasy
# 3  126556.0  tt0129960   tvMovie  Eine geschlossene Gesellschaft
# 4  166388.0  tt0172112     short                        Ambulans
#
#                     originalTitle  isAdult  startYear  endYear  \
# 0                           Kokoa      0.0     2019.0      NaN
# 1             Martina's Playhouse      0.0     2019.0      NaN
# 2             Mariette in Ecstasy      0.0     2019.0      NaN
# 3  Eine geschlossene Gesellschaft      0.0     2019.0      NaN
# 4                        Ambulans      0.0     2019.0      NaN
#
#    runtimeMinutes  genres
# 0            13.0     NaN
# 1            20.0     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4            11.0     NaN

# %% [markdown]
# ###  Q. 2

# %%
print(IMDB.titleType.value_counts())
unique =IMDB['titleType'].nunique()
print("Number Unique values:", unique)
# Out:
# tvEpisode       225972
# short            35351
# movie            15640
# video            10450
# tvSeries          7154
# tvMovie           2431
# tvMiniSeries      2000
# tvSpecial         1306
# videoGame          884
# tvShort            151
# Name: titleType, dtype: int64
# Number Unique values: 10

# %% [markdown]
# ### Q. 3

# %%
TPYR = IMDB.loc[:,["titleType","primaryTitle", "startYear","runtimeMinutes"]]
TPYR
# Out:
#         titleType                                       primaryTitle  \
# 0           short                                              Kokoa
# 1           short                                Martina's Playhouse
# 2           movie                                Mariette in Ecstasy
# 3         tvMovie                     Eine geschlossene Gesellschaft
# 4           short                                           Ambulans
# ...           ...                                                ...
# 301334  tvEpisode  Talent Coaching with IMOR's Bianca Desmore Mit...
# 301335  tvEpisode                                             Escape
# 301336  tvEpisode                                      Tinne Oltmans
# 301337  tvEpisode                                       Luc Janssens
# 301338  tvEpisode                       Danira Boukhriss Terkessidis
#
#         startYear  runtimeMinutes
# 0          2019.0            13.0
# 1          2019.0            20.0
# ...

# %% [markdown]
# ### Q. 4

# %%
tvEpisodes=IMDB.loc[IMDB["titleType"]=="tvEpisode"]
tvEpisodes
# Out:
#             index      tconst  titleType  \
# 21       758955.0   tt0782666  tvEpisode
# 30       969426.0  tt10001058  tvEpisode
# 32       969458.0  tt10001110  tvEpisode
# 34       969464.0  tt10001120  tvEpisode
# 35       969465.0  tt10001122  tvEpisode
# ...           ...         ...        ...
# 301334  6591633.0   tt9916776  tvEpisode
# 301335  6591634.0   tt9916778  tvEpisode
# 301336  6591640.0   tt9916790  tvEpisode
# 301337  6591646.0   tt9916802  tvEpisode
# 301338  6591650.0   tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 21                                     Save the Duckling!
# 30                                          Le grand saut
# 32                                         The Interviews
# 34                                            The New Guy
# 35                                           The New Girl
# ...                                                   ...
# ...

# %% [markdown]
# ### Q. 5

# %%
adult = IMDB['isAdult'].mean()*100
print ("Percente adult films / total release 2019.: %s%%" % round(adult, 2))
# Out:
# Percente adult films / total release 2019.: 2.97%

# %% [markdown]
# ### Q. 6

# %%
IMDB.isna().sum()
# Out:
# index                  0
# tconst                 0
# titleType              0
# primaryTitle           1
# originalTitle          1
# isAdult                0
# startYear              0
# endYear           299192
# runtimeMinutes    221511
# genres            301339
# dtype: int64

# %%
IMDB.primaryTitle.dropna()
# Out:
# 0                                                     Kokoa
# 1                                       Martina's Playhouse
# 2                                       Mariette in Ecstasy
# 3                            Eine geschlossene Gesellschaft
# 4                                                  Ambulans
#                                 ...
# 301334    Talent Coaching with IMOR's Bianca Desmore Mit...
# 301335                                               Escape
# 301336                                        Tinne Oltmans
# 301337                                         Luc Janssens
# 301338                         Danira Boukhriss Terkessidis
# Name: primaryTitle, Length: 301338, dtype: object

# %%
IMDB.primaryTitle.value_counts()
# Out:
# adult_movie_name            8945
# Episode #1.1                1265
# Episode #1.2                1164
# Episode #1.3                1100
# Episode #1.4                1009
#                             ...
# Kiss Burn                      1
# Underground City               1
# Jassie Gill: Surma Kaala       1
# Suspense                       1
# Purushottam                    1
# Name: primaryTitle, Length: 195513, dtype: int64

# %%
def words_title(IMDB):
    IMDB['totalwords'] = IMDB['primaryTitle'].str.count('') + 1
words_title(IMDB)
IMDB
# Out:
#             index     tconst  titleType  \
# 0         87501.0  tt0089435      short
# 1         89512.0  tt0091490      short
# 2        114407.0  tt0116991      movie
# 3        126556.0  tt0129960    tvMovie
# 4        166388.0  tt0172112      short
# ...           ...        ...        ...
# 301334  6591633.0  tt9916776  tvEpisode
# 301335  6591634.0  tt9916778  tvEpisode
# 301336  6591640.0  tt9916790  tvEpisode
# 301337  6591646.0  tt9916802  tvEpisode
# 301338  6591650.0  tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 0                                                   Kokoa
# 1                                     Martina's Playhouse
# 2                                     Mariette in Ecstasy
# 3                          Eine geschlossene Gesellschaft
# 4                                                Ambulans
# ...                                                   ...
# 301334  Talent Coaching with IMOR's Bianca Desmore Mit...
# ...

# %% [markdown]
# ### Q. 7

# %%
runtime = IMDB.loc[IMDB["titleType"] =="short"].runtimeMinutes.mean()
print ("Average runtimeMinutes is: %s" % round(runtime,2))
# Out:
# Average runtimeMinutes is: 12.54

# %% [markdown]
# ### Q. 8

# %%
IMDB.loc[(IMDB["titleType"]=="tvMovie") 
         & (IMDB["totalwords"]>=3) 
         & (IMDB["runtimeMinutes"]< 75)]
# Out:
#             index      tconst titleType  \
# 10       290068.0   tt0302617   tvMovie
# 77       970092.0  tt10002188   tvMovie
# 655      972490.0  tt10006422   tvMovie
# 870      974152.0  tt10009314   tvMovie
# 1549     977406.0  tt10015036   tvMovie
# ...           ...         ...       ...
# 300451  6587871.0   tt9908916   tvMovie
# 300975  6590161.0   tt9913680   tvMovie
# 301155  6591048.0   tt9915520   tvMovie
# 301240  6591316.0   tt9916112   tvMovie
# 301247  6591353.0   tt9916192   tvMovie
#
#                                        primaryTitle  \
# 10                            Great Bear Rainforest
# 77                   La Sagi, una pionera del Barça
# 655                        Warrior Women of Dahomey
# 870                  Peter Kraus: Immer in Bewegung
# 1549                      Arts Across the Heartland
# ...                                             ...
# 300451        Restless Legs Syndrome: The New Cure?
# 300975                        Olympiad drömmen 2020
# ...
